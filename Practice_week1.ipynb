# %%
import pandas as pd

# %%
df = pd.read_csv('/content/MLP_25T3_Preprocessing_V1.csv')

# %%
print(df.head())
# Out:
#   Employee_ID        Age Department  Experience_Years  Work_Hours_Per_Week  \
# 0      E03813  57.905751       Tech         26.857294            45.250284
# 1      E03637  63.487692    Finance         36.268848            24.701440
# 2      E00083  17.596337       tech          0.000000            44.802432
# 3      E07671  30.535083    Support         12.715795            38.840241
# 4      E06420  47.457249    Finance         32.388745            38.649167
#
#    Projects_Handled  Training_Score Remote_Work  Productivity_Score
# 0          8.025760       70.685144          No           40.655208
# 1          3.664293       82.893358         Yes           43.904473
# 2          4.246850       97.839530          No           33.404878
# 3          4.141745       43.547259          No           24.377786
# 4          4.766224       62.982486          No           22.413580

# %%
df.loc[3, 'Age']
# Out:
# np.float64(30.53508293936504)

# %%
df.loc[3, ['Age', 'Department']]
# Out:
# Age           30.535083
# Department      Support
# Name: 3, dtype: object

# %%
df.iloc[3, 1]
# Out:
# np.float64(30.53508293936504)

# %%
df.iloc[3, 1:3]
# Out:
# Age           30.535083
# Department      Support
# Name: 3, dtype: object

# %%
df.iloc[2,[1,2,3,4]]
# Out:
# Age                    17.596337
# Department                  tech
# Experience_Years             0.0
# Work_Hours_Per_Week    44.802432
# Name: 2, dtype: object

# %%
print(df.tail())
# Out:
#      Employee_ID        Age Department  Experience_Years  Work_Hours_Per_Week  \
# 5910      E05082  35.453144       Tech               NaN            59.132881
# 5911      E07852  39.403787       Tech         18.287206            33.711375
# 5912      E09015  41.712840       tech         30.205071            44.414641
# 5913      E08979  49.631892    Finance         25.851516            48.223210
# 5914      E02338  36.095628         hr         15.613875            48.047865
#
#       Projects_Handled  Training_Score Remote_Work  Productivity_Score
# 5910          2.178298      100.559452         Yes           35.006599
# 5911          4.781680       47.599589          No           20.225800
# 5912          4.263617       42.295560          No           33.771233
# 5913          6.172785       58.824965          No           28.260986
# 5914          3.659487       52.052870          No           19.359052

# %%
df
# Out:
#      Employee_ID        Age Department  Experience_Years  Work_Hours_Per_Week  \
# 0         E03813  57.905751       Tech         26.857294            45.250284
# 1         E03637  63.487692    Finance         36.268848            24.701440
# 2         E00083  17.596337       tech          0.000000            44.802432
# 3         E07671  30.535083    Support         12.715795            38.840241
# 4         E06420  47.457249    Finance         32.388745            38.649167
# ...          ...        ...        ...               ...                  ...
# 5910      E05082  35.453144       Tech               NaN            59.132881
# 5911      E07852  39.403787       Tech         18.287206            33.711375
# 5912      E09015  41.712840       tech         30.205071            44.414641
# 5913      E08979  49.631892    Finance         25.851516            48.223210
# 5914      E02338  36.095628         hr         15.613875            48.047865
#
# ...

# %%
df.loc[df.Projects_Handled < 6.172785]
# Out:
#      Employee_ID        Age Department  Experience_Years  Work_Hours_Per_Week  \
# 1         E03637  63.487692    Finance         36.268848            24.701440
# 2         E00083  17.596337       tech          0.000000            44.802432
# 3         E07671  30.535083    Support         12.715795            38.840241
# 4         E06420  47.457249    Finance         32.388745            38.649167
# 5         E02028  49.019017    Finance         34.637479            50.720012
# ...          ...        ...        ...               ...                  ...
# 5910      E05082  35.453144       Tech               NaN            59.132881
# 5911      E07852  39.403787       Tech         18.287206            33.711375
# 5912      E09015  41.712840       tech         30.205071            44.414641
# 5913      E08979  49.631892    Finance         25.851516            48.223210
# 5914      E02338  36.095628         hr         15.613875            48.047865
#
# ...

# %%
x = df.loc[df.Projects_Handled < 6.172785]

# %%
x.loc[5]
# Out:
# Employee_ID               E02028
# Age                    49.019017
# Department               Finance
# Experience_Years       34.637479
# Work_Hours_Per_Week    50.720012
# Projects_Handled        4.053286
# Training_Score          53.07023
# Remote_Work                   No
# Productivity_Score     31.002414
# Name: 5, dtype: object

# %%
df.shape
# Out:
# (5915, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5915 entries, 0 to 5914
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          5915 non-null   object
#  1   Age                  5794 non-null   float64
#  2   Department           5786 non-null   object
#  3   Experience_Years     5802 non-null   float64
#  4   Work_Hours_Per_Week  5915 non-null   float64
#  5   Projects_Handled     5915 non-null   float64
#  6   Training_Score       5790 non-null   float64
#  7   Remote_Work          5915 non-null   object
#  8   Productivity_Score   5915 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 416.0+ KB

# %%
list(df.columns)
# Out:
# ['Employee_ID',
#  'Age',
#  'Department',
#  'Experience_Years',
#  'Work_Hours_Per_Week',
#  'Projects_Handled',
#  'Training_Score',
#  'Remote_Work',
#  'Productivity_Score']

# %%
df.describe()
# Out:
#                Age  Experience_Years  Work_Hours_Per_Week  Projects_Handled  \
# count  5794.000000       5802.000000          5915.000000       5915.000000
# mean     40.552771         18.245573            40.215658          5.036465
# std      13.466786         12.034101             9.371364          2.464778
# min      14.843586          0.000000            19.093269          0.000000
# 25%      29.835508          8.257665            33.196744          3.274530
# 50%      39.287529         17.522587            39.729889          4.726955
# 75%      49.784502         27.332972            46.263209          6.492976
# max      77.901090         52.735789           154.188435         16.844048
#
#        Training_Score  Productivity_Score
# count     5790.000000         5915.000000
# mean        70.000352           28.533375
# std         19.593183            8.824069
# min         11.179777            0.000000
# 25%         55.645554           22.230133
# ...

# %%
df['Department']
# Out:
# 0          Tech
# 1       Finance
# 2          tech
# 3       Support
# 4       Finance
#          ...
# 5910       Tech
# 5911       Tech
# 5912       tech
# 5913    Finance
# 5914         hr
# Name: Department, Length: 5915, dtype: object

# %%
type(df['Department'])
# Out:
# pandas.core.series.Series

# %%
df['Department'][0]
# Out:
# 'Tech'

# %%
df['Department'][:4]
# Out:
# 0       Tech
# 1    Finance
# 2       tech
# 3    Support
# Name: Department, dtype: object

# %%
df['Department'][-3:]
# Out:
# 5912       tech
# 5913    Finance
# 5914         hr
# Name: Department, dtype: object

# %%
df[['Department','Experience_Years']]
# Out:
#      Department  Experience_Years
# 0          Tech         26.857294
# 1       Finance         36.268848
# 2          tech          0.000000
# 3       Support         12.715795
# 4       Finance         32.388745
# ...         ...               ...
# 5910       Tech               NaN
# 5911       Tech         18.287206
# 5912       tech         30.205071
# 5913    Finance         25.851516
# 5914         hr         15.613875
#
# [5915 rows x 2 columns]

# %%
df[['Department','Experience_Years']][:5]
# Out:
#   Department  Experience_Years
# 0       Tech         26.857294
# 1    Finance         36.268848
# 2       tech          0.000000
# 3    Support         12.715795
# 4    Finance         32.388745

# %%
df[['Department','Experience_Years']][-5:]
# Out:
#      Department  Experience_Years
# 5910       Tech               NaN
# 5911       Tech         18.287206
# 5912       tech         30.205071
# 5913    Finance         25.851516
# 5914         hr         15.613875

# %%
df[['Department','Experience_Years']][5:6]
# Out:
#   Department  Experience_Years
# 5    Finance         34.637479

# %%
df.isnull().sum()
# Out:
# Employee_ID              0
# Age                    121
# Department             129
# Experience_Years       113
# Work_Hours_Per_Week      0
# Projects_Handled         0
# Training_Score         125
# Remote_Work              0
# Productivity_Score       0
# dtype: int64

# %%
pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme
sns.histplot([1,2,2,3,3,3,4,4,5])
plt.show()

# %%
df.head()
# Out:
#   Employee_ID        Age Department  Experience_Years  Work_Hours_Per_Week  \
# 0      E03813  57.905751       Tech         26.857294            45.250284
# 1      E03637  63.487692    Finance         36.268848            24.701440
# 2      E00083  17.596337       tech          0.000000            44.802432
# 3      E07671  30.535083    Support         12.715795            38.840241
# 4      E06420  47.457249    Finance         32.388745            38.649167
#
#    Projects_Handled  Training_Score Remote_Work  Productivity_Score
# 0          8.025760       70.685144          No           40.655208
# 1          3.664293       82.893358         Yes           43.904473
# 2          4.246850       97.839530          No           33.404878
# 3          4.141745       43.547259          No           24.377786
# 4          4.766224       62.982486          No           22.413580

# %%
sns.scatterplot(data=df,x="Age", y="Work_Hours_Per_Week")
plt.show()

# %%
sns.set_theme
sns.histplot(df, x="Department")
plt.show()

# %%
corr = df.corr(numeric_only = True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(corr, annot = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.isnull().sum()
# Out:
# Employee_ID              0
# Age                    121
# Department             129
# Experience_Years       113
# Work_Hours_Per_Week      0
# Projects_Handled         0
# Training_Score         125
# Remote_Work              0
# Productivity_Score       0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Age', 'Department', 'Experience_Years', 'Training_Score']

# %%
sns.heatmap(df.isnull())

# %%
c = pd.Series(['Mum','kol','loc','kite'])
p = pd.Series([1344,1245,4578,23567])

# %%
data = pd.DataFrame({'city':c, 'population':p})

# %%
data
# Out:
#    city  population
# 0   Mum        1344
# 1   kol        1245
# 2   loc        4578
# 3  kite       23567

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Department', 'Experience_Years',
#        'Work_Hours_Per_Week', 'Projects_Handled', 'Training_Score',
#        'Remote_Work', 'Productivity_Score'],
#       dtype='object')

# %%
df.head()
# Out:
#   Employee_ID        Age Department  Experience_Years  Work_Hours_Per_Week  \
# 0      E03813  57.905751       Tech         26.857294            45.250284
# 1      E03637  63.487692    Finance         36.268848            24.701440
# 2      E00083  17.596337       tech          0.000000            44.802432
# 3      E07671  30.535083    Support         12.715795            38.840241
# 4      E06420  47.457249    Finance         32.388745            38.649167
#
#    Projects_Handled  Training_Score Remote_Work  Productivity_Score
# 0          8.025760       70.685144          No           40.655208
# 1          3.664293       82.893358         Yes           43.904473
# 2          4.246850       97.839530          No           33.404878
# 3          4.141745       43.547259          No           24.377786
# 4          4.766224       62.982486          No           22.413580

# %%
df['Remote_Work'] == 'Yes'
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 5910     True
# 5911    False
# 5912    False
# 5913    False
# 5914    False
# Name: Remote_Work, Length: 5915, dtype: bool

# %%
df.Department == 'Finance'
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 5910    False
# 5911    False
# 5912    False
# 5913     True
# 5914    False
# Name: Department, Length: 5915, dtype: bool

# %%
df['Department'] == 'Finance'
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 5910    False
# 5911    False
# 5912    False
# 5913     True
# 5914    False
# Name: Department, Length: 5915, dtype: bool

# %%
condition_met = df.Department == 'Finance'
type(condition_met)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Aggregtion And Grouping**

# %%
import numpy as np
import pandas as pd

# %%
random_state = np.random.RandomState(100)
random_series = pd.Series(random_state.rand(10))

# %%
random_series
# Out:
# 0    0.543405
# 1    0.278369
# 2    0.424518
# 3    0.844776
# 4    0.004719
# 5    0.121569
# 6    0.670749
# 7    0.825853
# 8    0.136707
# 9    0.575093
# dtype: float64

# %%
df = pd.DataFrame({'A': random_state.rand(5),
                   'B': random_state.rand(5)})
df
# Out:
#           A         B
# 0  0.891322  0.978624
# 1  0.209202  0.811683
# 2  0.185328  0.171941
# 3  0.108377  0.816225
# 4  0.219697  0.274074

# %%
df.sum()
# Out:
# A    1.613927
# B    3.052546
# dtype: float64

# %%
df.mean()
# Out:
# A    0.322785
# B    0.610509
# dtype: float64

# %%
df.std()
# Out:
# A    0.320791
# B    0.361880
# dtype: float64
